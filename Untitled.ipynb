# %%
import numpy as np

def cross_entropy(Y, P):
    Y = np.float_(Y)
    P = np.float_(P)
    return -np.sum(Y * np.log(P) + (1 - Y) * np.log(1 - P))

x = cross_entropy(1,0.4)
print(x)
# Out:
# 0.916290731874155
